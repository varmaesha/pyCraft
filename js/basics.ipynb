# %% [markdown]
# Synchronocus Single threaded => one command at a time
# - Execution Context Global/Local
#     - Memory/Variable Env
#         - Key-Value pair of var and funs
#         - Memory is allocated before execution to vars and funs
#     - Code/ Thread of Exe
#         - Code line by line
# - Call Stack
#     -
# Initially vars are undefined

# %% [markdown]
# Hoisting
#
# - Accessing without defining or initializing without encountering error
#
#     getName();
#     console.log(x)
#
#     var x = 7;
#     function getName(){
#         console.log("HI")
#     }
#
#     *OP*
#     undefined
#     HI

# %% [markdown]
# console.log(getName)
# function getName(){
#         console.log("HI")
#     }
#
# *OP*
#
# f getName(){
#         console.log("HI")
#     }

# %% [markdown]
# var x = 1;
# a();
# b();
# log-x
#
# function a(){
#     x=10;
#     log-x
# }
# function b(){
#     x=100;
#     log-x
# }
#
# *OP*
# 10
# 100
# 1

# %% [markdown]
# var a = 7;
# => a = undefined -> placeholder in memory
#
# log valu which is node defined give is not defined error
#
# clg-a
# var a = 10
# clg-a
# *OP*
# undefined
# 10
