# %%
// # objet toye is overridden by nubmer

let rV = {name:"Esja"}
rV = 28

if(!typeof rV == "string")
{
    console.log("Not string")
}
else{
    console.log("Yay string",rV\)
    console.log(typeof rV)
}

// # Yay string 28
// # test.js:10 number
# Out:
#   Cell In[1], line 3
#     let rV = {name:"Esja"}
#         ^
# SyntaxError: invalid syntax

# %%
const user = {
    em: "avb",
    updateEm: em=> {
        // console.log(this) // Output: Window
        this.em = em
        // # this references to lexical context not users
        // console.log(this) // Output: Window
    }
}

user.updateEm("aaa")
console.log(user.em) // Output: "avb"

# %%
const fruits = ['apple', 'banana', 'orange']
k= fruits.slice(2)// index returns array
console.log(k)
l= fruits.splice(0,1)//returns element removed
console.log(l)
fruits.unshift('kiwi')//add element at the beginning
console.log(fruits)
// ['orange']
// test.js:5 ['apple']
// test.js:7 (3) ['kiwi', 'banana', 'orange']

# %%
class Calc{
    constructor(){
        this.count = 0
    }
    increase(){
        this.count++
    }
}
const calc = new Calc()
new Calc().increase()

console.log(calc.count) // Output: 0

# %%
let count = 0;
const num = [1, 2, 3,11];
num.forEach(n => {
    if (n) count+=1
});
console.log(count);
// Output: 4

# %%
class Bird{
    constructor(){
        console.log("Bird")
    }
}

class Flamin extends Bird{
    constructor(){
        console.log("Im pink");
        super();
    }
}

const pet =  new Flamin();
// Output: Im pink
// Output: Bird

# %%
class Counter{
    #number = 10
    increment(){
        this.#number++
    }   
    getNum(){
        return this.#number
    }
}

const counter = new Counter()
counter.increment()
console.log(counter.getNum())// Output: 11
// console.log(counter.#number)// syntax error

# %%
const add = x => x+x;

function myF(num = 2,value = add(num)){
    console.log(num,value);
}

myF();// Output: 2 4
myF(3);// Output: 3 6

# %%
const handler = {
    set:()=>console.log('set'),
    get:()=>console.log('get'),
}

const person = new Proxy({}, handler);
person.name = '张三'; // set
person.name; // get
